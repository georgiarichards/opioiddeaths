# %% [markdown]
# # Scraping the Courts and Tribunals Judiciary Website for Prevent Future Death Reports

# %%
from requests import get
from requests import ConnectionError
from bs4 import BeautifulSoup
import re
from time import sleep
from time import time
import csv

try:
    get_ipython
    from tqdm import tqdm_notebook as tqdm
except NameError:
    from tqdm import tqdm
    
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
    
def get_url(url):
    response = get(url, verify = False)
    html = response.content
    soup = BeautifulSoup(html, "html.parser")
    return soup

# %% [markdown]
# # Scraper starts here - this was run on Wednesday, Aug 12 2020 at 11.00 am.

# %%
#Your second value in "range" will be one more than the number of pages that exist on the wesbite
pages = list(range(1,326))

#This loops through all the pages to get the URLs to individual records
page_string = 'https://www.judiciary.uk/subject/prevention-of-future-deaths/page/{}/'
record_urls = []
for page in tqdm(pages):
    soup = get_url(page_string.format(str(page)))
    h5s = soup.find_all('h5', {'class': 'entry-title'})
    for h5 in h5s:
        record_urls.append(h5.a.get('href'))
# Out:
# HBox(children=(IntProgress(value=0, max=325), HTML(value='')))

# %% [markdown]
# Here we check how many records (i.e. cases) were pulled from the urls & the first and last case

# %%
len(record_urls)
# Out:
# 3242

# %%
record_urls[0]
# Out:
# 'https://www.judiciary.uk/publications/michael-pender/'

# %%
record_urls[-1]
# Out:
# 'https://www.judiciary.uk/publications/phillip-pratt/'

# %% [markdown]
# Here is my second loop. This will go through the lists of URLs I just created above to visit each individual record and pull out and store the text data (info on the decreased/case) and the PDF URL I will use later

# %%
reg_exp = re.compile(r"’s\s|s\s|'s\s")
text_cats = ['Date of report', 'Ref', 'Deceased name', 'Coroner name', 'Coroner Area', 'Category', "This report is being sent to"]
#First, I create two lists, one for the PDFs and one for the text data
record_text = []
pdf_urls = []
ref_list = []
#I want to loop through each URL & pull out the death information and pdf link for downloading 
for record_url in tqdm(record_urls):
    #This is just a way to retry reaching the website incase there is a temporary error in reaching a specific page
    #If it fails more than 3 times, then you will get an error, but this protects against a temporary blip ruining 
    #the scrape
    try:
        tries = 3
        for i in range(tries):
            try:
                soup = get_url(record_url)
            except (ConnectionError, SSLError):
                if i < tries - 1:
                    sleep(2)
                    continue
                else:
                    raise
        #This gets all the text fields from the website to work with
        death_info = soup.find('div', {'class':'entry-content'}).find_all('p')
        #Our dictionary that will hold all of the text information that we will eventually append to "record_text"
        blankdict = {}
        #This is to handle 1 annoying record with messed up html tags
        if record_url == 'https://www.judiciary.uk/publications/roadsafety/':
            strong = death_info[0].find_all('strong')
            heads = ['date_of_report', 'ref', 'deceased_name', 'coroner_name', 'coroner_area', 'category']
            for st, h in zip(strong,heads):
                blankdict[h] = st.next_sibling.replace(':',"").strip()
        #looping through all of the text categories for handling
        for p in death_info:
            #This checks for blank fields and if there is nothing, it skips it
            if p.text.strip() == '':
                pass
            #This checks for our "Normal" case in which a colon exists and the category is one of the ones we 
            #pre-specified above in the "text_cats" list
            #We also need to account here for one strange record for "Rebecca Evans" which has a weird text error
            #That we manually correct for
            elif ':' in p.text and p.text.split(':')[0] in text_cats and not 'Rebecca-EvansR.pdf' in p.text:
                #Simply assigning the key and value from strings on either side of the colon, making everything 
                #lower case and replacing spaces with underscores and also removing any stray semi-colons
                text_list = p.text.split(':')
                blankdict[text_list[0].strip().replace(' ','_').lower()] = text_list[1].strip().replace('\n','')
                    
            elif 'Rebecca-EvansR.pdf' in p.text:
                #This deals with that singular odd record that currently exists as of 8 Nov 2019
                blankdict['category'] = p.text.split(':')[1].strip().replace('\n','')
            elif ':' not in p.text:
                #If the string doesn't have a colon, we can't split on it so have to get it into dictionary format
                #Using an alternate method that counts the length of the thing
                if any(x in p.text for x in text_cats):
                    t = [x for x in text_cats if x in p.text][0]
                    l = len(t)
                    blankdict[t.replace(' ','_').lower()] = p.text[l+1:].replace('\n','')
                elif 'Coroners Area' in p.text:
                    blankdict['coroner_area'] = p.text[13:].strip().replace('\n','')
                else:
                    print("Something we haven't accounted for has happened")
            
            elif p.text.strip().count(":") == 2:
                #This corrects for one odd record in which there are 2 colons but should generalize to fix it for
                #any time this could happen, so long as it happens in the same way
                text_list = p.text.split(':')
                new_string = text_list[0] + text_list[1]
                new_name = re.sub(reg_exp, ' ', new_string).strip()
                blankdict[new_name.replace(' ','_').lower()] = text_list[2].strip().replace('\n','')
            
            elif ':' in p.text and p.text.split(':')[0] not in text_cats:
                #Some field names are in the form of "name_of_decesased" or "name_of_coroner" or are plural/
                #possessive so this smashes those into our preferred naming formats
                if 'Name of' in p.text:
                    all_text = p.text.split(':')
                    key_name = all_text[0].split(' ')
                    blankdict[key_name[2].strip() + '_name'] = all_text[-1].strip()
                else:    
                    new_name = re.sub(reg_exp, ' ', p.text)
                    text_list = new_name.split(':')
                    blankdict[text_list[0].strip().replace(' ','_').lower()] = text_list[1].strip().replace('\n','')
        blankdict['url'] = record_url
        try:
            if not blankdict['ref']:
                pass
            elif blankdict['ref'] in ref_list:
                blankdict['ref'] = blankdict['ref'] + 'A'
            ref_list.append(blankdict['ref'])
        except KeyError:
            blankdict['ref'] = ''
        #This appends the final dict to the list
        record_text.append(blankdict)
        #this is a seperate process to get the PDF URLs (no matter how many there are) and adds them to their own list   
        urls = soup.find_all('li', {'class':'pdf'})
        pdf_list = []
        for url in urls:
            pdf_list.append(url.findNext('a').get('href'))
        pdf_urls.append(pdf_list)
    except Exception as e:
        #This is an exception catcher to give useful feedback for debugging
        import sys
        raise type(e)(str(e) + '\n' + 'Error for Record: {}, Field: {}'.format(record_url, p)).with_traceback(sys.exc_info()[2])
# Out:
# HBox(children=(IntProgress(value=0, max=3242), HTML(value='')))

# %% [markdown]
# Here is the third loop to save the PDFs using the deceased Ref as the file name

# %%
#This is the final scrape to actually get the URLs and change the name (when possible) to the refs
for r_t, p_u in zip(tqdm(record_text), pdf_urls):
    if len(p_u) == 0:
        #If there is no pdf at all, we skip it.
        pass
    else:
        #All this does is gets the PDF and downloads it and names it after the reg
        #It looks scary and complicated but all it is doing is varying the name in the case of multiple PDFs
        #Or naming it for the deceased person if there is no Ref value
        #If there is a pdf but no ref or deceased name, this will throw an error and we can adjust.
        try:
            counter = 0
            if len(p_u) > 1:
                for p in p_u:
                    if counter == 0:
                        myfile = get(p)
                        if r_t['ref']:
                            with open('/Users/georgiarichards/Desktop/Python/PFDs opioids/All_PDFs5/{}.pdf'.format(r_t['ref']), 'wb') as d:
                                d.write(myfile.content)
                            counter +=1
                        else:
                            with open('/Users/georgiarichards/Desktop/Python/PFDs opioids/All_PDFs5/{}.pdf'.format(r_t['deceased_name']), 'wb') as d:
                                d.write(myfile.content)
                            counter +=1
                    else:
                        myfile = get(p)
                        if r_t['ref']:
                            with open('/Users/georgiarichards/Desktop/Python/PFDs opioids/All_PDFs5/{}_{}.pdf'.format(r_t['ref'], str(counter)), 'wb') as d:
                                d.write(myfile.content)
                            counter +=1
                        else:
                            with open('/Users/georgiarichards/Desktop/Python/PFDs opioids/All_PDFs5/{}_{}.pdf'.format(r_t['deceased_name'], str(counter)), 'wb') as d:
                                d.write(myfile.content)
                            counter +=1
            else:
                myfile = get(p_u[0])
                if r_t['ref']:
                    with open('/Users/georgiarichards/Desktop/Python/PFDs opioids/All_PDFs5/{}.pdf'.format(r_t['ref']), 'wb') as d:
                        d.write(myfile.content)
                else:
                    with open('/Users/georgiarichards/Desktop/Python/PFDs opioids/All_PDFs5/{}.pdf'.format(r_t['deceased_name']), 'wb') as d:
                        d.write(myfile.content)
        except Exception as e:
            import sys
            if r_t['ref']:
                raise type(e)(str(e) + '\n' + 'Error for Record: {}'.format(r_t['ref'])).with_traceback(sys.exc_info()[2])
            else:
                raise type(e)(str(e) + '\n' + 'Error for Record: {}'.format(r_t['deceased_name'])).with_traceback(sys.exc_info()[2])
# Out:
# HBox(children=(IntProgress(value=0, max=3242), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-7f302289a96d> in <module>
#      40                 else:
# ---> 41                     with open('/Users/georgiarichards/Desktop/Python/PFDs opioids/All_PDFs5/{}.pdf'.format(r_t['deceased_name']), 'wb') as d:
#      42                         d.write(myfile.content)
#
# KeyError: 'deceased_name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-7f302289a96d> in <module>
#      46                 raise type(e)(str(e) + '\n' + 'Error for Record: {}'.format(r_t['ref'])).with_traceback(sys.exc_info()[2])
#      47             else:
# ---> 48                 raise type(e)(str(e) + '\n' + 'Error for Record: {}'.format(r_t['deceased_name'])).with_traceback(sys.exc_info()[2])
#
# KeyError: 'deceased_name'

# %% [markdown]
# This is my final step that puts the text data (info on the decreased/case) into a csv file & adds the date it was pulled

# %%
from datetime import date

headers = ['date_of_report', 'ref', 'deceased_name', 'coroner_name', 'coroner_area', 'category', "this_report_is_being_sent_to", "url"]

with open('death_info_{}.csv'.format(date.today()), 'w', newline='', encoding='utf-8') as deaths_csv:
    writer = csv.DictWriter(deaths_csv, fieldnames=headers)
    writer.writeheader()
    for record in record_text:
        if record == {}:
            pass
        else:
            writer.writerow(record)

# %% [markdown]
# This is an addition few steps to check what differences there are from the Dec month records

# %%
import os

pdfs4 = os.listdir('All_PDFs4')
pdfs5 = os.listdir('All_PDFs5')

new_not_old = set(pdfs5).difference(pdfs4)

new_not_old_list = list(new_not_old)
new_not_old_list.sort()
new_not_old_list
# Out:
# ['2013-0303_1.pdf',
#  '2013-0347A_1.pdf',
#  '20130-0251_3.pdf',
#  '2014-0336_2.pdf',
#  '2014-0479_3.pdf',
#  '2014-0558A_1.pdf',
#  '2014-0560_1.pdf',
#  '2015-0013_2.pdf',
#  '2015-0062_1.pdf',
#  '2015-0080_1.pdf',
#  '2015-0090_1.pdf',
#  '2015-0100A_1.pdf',
#  '2015-0100_1.pdf',
#  '2015-0102A_2.pdf',
#  '2015-0102_2.pdf',
#  '2015-0106_2.pdf',
#  '2015-0137_1.pdf',
#  '2015-0172_1.pdf',
#  '2015-0181_1.pdf',
#  '2015-0201_2.pdf',
#  '2015-0212_1.pdf',
#  '2015-0233_1.pdf',
#  '2015-0233_2.pdf',
#  '2015-0233_3.pdf',
#  '2015-0240_1.pdf',
#  '2015-0245_2.pdf',
#  '2015-0246_1.pdf',
#  '2015-0252_1.pdf',
#  '2015-0252_2.pdf',
#  '2015-0252_3.pdf',
#  '2015-0254_1.pdf',
#  '2015-0255_1.pdf',
#  '2015-0258_1.pdf',
#  '2015-0259_1.pdf',
#  '2015-0260_1.pdf',
#  '2015-0264_1.pdf',
#  '2015-0268_1.pdf',
#  '2015-0271_1.pdf',
#  '2015-0272_1.pdf',
#  '2015-0274_1.pdf',
#  '2015-0275_1.pdf',
#  '2015-0276_2.pdf',
#  '2015-0276_3.pdf',
#  '2015-0276_4.pdf',
#  '2015-0278_1.pdf',
#  '2015-0279_1.pdf',
#  '2015-0283_1.pdf',
#  '2015-0284_1.pdf',
#  '2015-0289_2.pdf',
#  '2015-0290_1.pdf',
#  '2015-0291_1.pdf',
#  '2015-0293_1.pdf',
#  '2015-0294_1.pdf',
#  '2015-0296_1.pdf',
#  '2015-0297_1.pdf',
#  '2015-0298_1.pdf',
#  '2015-0301_1.pdf',
#  '2015-0303_1.pdf',
#  '2015-0304_1.pdf',
#  '2015-0305_1.pdf',
#  '2015-0307_1.pdf',
#  '2015-0308_1.pdf',
#  '2015-0309_1.pdf',
#  '2015-0312_1.pdf',
#  '2015-0313_2.pdf',
#  '2015-0315_1.pdf',
#  '2015-0315_2.pdf',
#  '2015-0315_3.pdf',
#  '2015-0318_1.pdf',
#  '2015-0319_1.pdf',
#  '2015-0366.pdf',
#  '2015-0367_1.pdf',
#  '2015-0369A_1.pdf',
#  '2015-0369_1.pdf',
#  '2015-0374_1.pdf',
#  '2015-0380_3.pdf',
#  '2015-0380_4.pdf',
#  '2015-0381_1.pdf',
#  '2015-0382_1.pdf',
#  '2015-0384_2.pdf',
#  '2015-0388_1.pdf',
#  '2015-0393_1.pdf',
#  '2015-0394_1.pdf',
#  '2015-0398_1.pdf',
#  '2015-0400_1.pdf',
#  '2015-0402_1.pdf',
#  '2015-0404_1.pdf',
#  '2015-0406_1.pdf',
#  '2015-0419_1.pdf',
#  '2015-0421A_1.pdf',
#  '2015-0454_2.pdf',
#  '2015-0454_3.pdf',
#  '2015-0458_1.pdf',
#  '2015-0507_1.pdf',
#  '2016-0358_1.pdf',
#  '2016-0380_1.pdf',
#  '2017-00359_1.pdf',
#  '2017-0165_1.pdf',
#  '2017-0211A.pdf',
#  '2017-0226_1.pdf',
#  '2017-0227_1.pdf',
#  '2017-0245_1.pdf',
#  '2017-0278_1.pdf',
#  '2017-0290_2.pdf',
#  '2017-0294_1.pdf',
#  '2017-0303_2.pdf',
#  '2017-0307_1.pdf',
#  '2017-0307_2.pdf',
#  '2017-0308_1.pdf',
#  '2017-0310_1.pdf',
#  '2017-0345_1.pdf',
#  '2017-0346_1.pdf',
#  '2017-0348_1.pdf',
#  '2017-0349_1.pdf',
#  '2017-0350_1.pdf',
#  '2017-0350_2.pdf',
#  '2017-0351_1.pdf',
#  '2017-0352_1.pdf',
#  '2017-0353_1.pdf',
#  '2017-0356_1.pdf',
#  '2017-0356_2.pdf',
#  '2017-0356_3.pdf',
#  '2017-0357_1.pdf',
#  '2017-0360_1.pdf',
#  '2017-0361_1.pdf',
#  '2017-0361_2.pdf',
#  '2017-0362_1.pdf',
#  '2017-0363_1.pdf',
#  '2017-0367_1.pdf',
#  '2017-0373_1.pdf',
#  '2017-0376_1.pdf',
#  '2017-0376_2.pdf',
#  '2017-0376_3.pdf',
#  '2017-0377_2.pdf',
#  '2017-0377_3.pdf',
#  '2017-0377_4.pdf',
#  '2017-0378_1.pdf',
#  '2017-0379_1.pdf',
#  '2017-0380_1.pdf',
#  '2017-0382_1.pdf',
#  '2017-0383_1.pdf',
#  '2017-0383_2.pdf',
#  '2017-0385_1.pdf',
#  '2017-0386_1.pdf',
#  '2017-0394_1.pdf',
#  '2017-0398_1.pdf',
#  '2017-0399_1.pdf',
#  '2017-0400_1.pdf',
#  '2017-0401_1.pdf',
#  '2017-0402_1.pdf',
#  '2017-0407_1.pdf',
#  '2017-0408_1.pdf',
#  '2017-0410_1.pdf',
#  '2017-0411_1.pdf',
#  '2017-0414_1.pdf',
#  '2017-0415_1.pdf',
#  '2017-0420_1.pdf',
#  '2017-0421_2.pdf',
#  '2017-0422_1.pdf',
#  '2017-0423_1.pdf',
#  '2017-0424_1.pdf',
#  '2017-0429_1.pdf',
#  '2017-0459_1.pdf',
#  '2017-0494_1.pdf',
#  '2018-0002_1.pdf',
#  '2018-0003_1.pdf',
#  '2018-0003_2.pdf',
#  '2018-0003_3.pdf',
#  '2018-0007_1.pdf',
#  '2018-0007_2.pdf',
#  '2018-0008_1.pdf',
#  '2018-0009_1.pdf',
#  '2018-0011_1.pdf',
#  '2018-0012_1.pdf',
#  '2018-0013_1.pdf',
#  '2018-0015_1.pdf',
#  '2018-0017_1.pdf',
#  '2018-0018_1.pdf',
#  '2018-0021_1.pdf',
#  '2018-0021_2.pdf',
#  '2018-0022_1.pdf',
#  '2018-0025_1.pdf',
#  '2018-0026_1.pdf',
#  '2018-0026_2.pdf',
#  '2018-0028_1.pdf',
#  '2018-0030_1.pdf',
#  '2018-0034_1.pdf',
#  '2018-0034_2.pdf',
#  '2018-0035_1.pdf',
#  '2018-0039_1.pdf',
#  '2018-0040_1.pdf',
#  '2018-0044_1.pdf',
#  '2018-0048_1.pdf',
#  '2018-0050_1.pdf',
#  '2018-0052_1.pdf',
#  '2018-0053_1.pdf',
#  '2018-0088_2.pdf',
#  '2018-0142_1.pdf',
#  '2018-0192_1.pdf',
#  '2018-0195_2.pdf',
#  '2018-0195_3.pdf',
#  '2018-0256_1.pdf',
#  '2018-0259_1.pdf',
#  '2018-0303_1.pdf',
#  '2018-0306_1.pdf',
#  '2018-0307_1.pdf',
#  '2018-0309_1.pdf',
#  '2018-0315_1.pdf',
#  '2018-0325_1.pdf',
#  '2018-0330_4.pdf',
#  '2018-0338_1.pdf',
#  '2018-0342_1.pdf',
#  '2018-0345_1.pdf',
#  '2018-0354_1.pdf',
#  '2018-0356_1.pdf',
#  '2018-0359.pdf',
#  '2018-0359_1.pdf',
#  '2018-0361_1.pdf',
#  '2018-0362_1.pdf',
#  '2018-0365_1.pdf',
#  '2018-0373_1.pdf',
#  '2018-0374_1.pdf',
#  '2018-0375_1.pdf',
#  '2018-0375_2.pdf',
#  '2018-0377_1.pdf',
#  '2018-0378_1.pdf',
#  '2018-0379_1.pdf',
#  '2018-0384_1.pdf',
#  '2018-0384_2.pdf',
#  '2018-0385_1.pdf',
#  '2018-0385_2.pdf',
#  '2018-0386_1.pdf',
#  '2018-0387_1.pdf',
#  '2018-0388_1.pdf',
#  '2018-0389_1.pdf',
#  '2018-0391_1.pdf',
#  '2018-0391_2.pdf',
#  '2018-0392_1.pdf',
#  '2018-0393_1.pdf',
#  '2018-0394_1.pdf',
#  '2018-0395_1.pdf',
#  '2018-0395_2.pdf',
#  '2018-0398_1.pdf',
#  '2018-0398_2.pdf',
#  '2018-0401_1.pdf',
#  '2018-0401_2.pdf',
#  '2018-0404_1.pdf',
#  '2018-0404_2.pdf',
#  '2018-0404_3.pdf',
#  '2018-0405_1.pdf',
#  '2018-0408_1.pdf',
#  '2018-0409_1.pdf',
#  '2018-0410_1.pdf',
#  '2018-0411_1.pdf',
#  '2018-0411_2.pdf',
#  '2018-0411_3.pdf',
#  '2018-0419_2.pdf',
#  '2019-0001_1.pdf',
#  '2019-0005_1.pdf',
#  '2019-0007_1.pdf',
#  '2019-0008_1.pdf',
#  '2019-0010_1.pdf',
#  '2019-0012_1.pdf',
#  '2019-0013_1.pdf',
#  '2019-0018_1.pdf',
#  '2019-0019_1.pdf',
#  '2019-0019_2.pdf',
#  '2019-0022_1.pdf',
#  '2019-0024_1.pdf',
#  '2019-0026_1.pdf',
#  '2019-0030_1.pdf',
#  '2019-0032_1.pdf',
#  '2019-0037_1.pdf',
#  '2019-0077_1.pdf',
#  '2019-0077_2.pdf',
#  '2019-0081_1.pdf',
#  '2019-0111_1.pdf',
#  '2019-0149_1.pdf',
#  '2019-0149_2.pdf',
#  '2019-0161_1.pdf',
#  '2019-0161_2.pdf',
#  '2019-0165_1.pdf',
#  '2019-0192_1.pdf',
#  '2019-0194_1.pdf',
#  '2019-0194_2.pdf',
#  '2019-0230_1.pdf',
#  '2019-0230_2.pdf',
#  '2019-0233_1.pdf',
#  '2019-0233_2.pdf',
#  '2019-0240_1.pdf',
#  '2019-0240_2.pdf',
#  '2019-0241_1.pdf',
#  '2019-0244_3.pdf',
#  '2019-0250_1.pdf',
#  '2019-0250_2.pdf',
#  '2019-0253_1.pdf',
#  '2019-0253_2.pdf',
#  '2019-0259_1.pdf',
#  '2019-0260_1.pdf',
#  '2019-0263_1.pdf',
#  '2019-0265_1.pdf',
#  '2019-0269_1.pdf',
#  '2019-0273_1.pdf',
#  '2019-0273_2.pdf',
#  '2019-0273_3.pdf',
#  '2019-0274_2.pdf',
#  '2019-0277_1.pdf',
#  '2019-0279_1.pdf',
#  '2019-0281_1.pdf',
#  '2019-0281_2.pdf',
#  '2019-0284_2.pdf',
#  '2019-0287_1.pdf',
#  '2019-0287_2.pdf',
#  '2019-0296_2.pdf',
#  '2019-0300_1.pdf',
#  '2019-0301_1.pdf',
#  '2019-0307_1.pdf',
#  '2019-0309_1.pdf',
#  '2019-0310_1.pdf',
#  '2019-0314A_1.pdf',
#  '2019-0314_1.pdf',
#  '2019-0316_1.pdf',
#  '2019-0316_2.pdf',
#  '2019-0317_1.pdf',
#  '2019-0327_1.pdf',
#  '2019-0331_1.pdf',
#  '2019-0332_1.pdf',
#  '2019-0332_2.pdf',
#  '2019-0332_3.pdf',
#  '2019-0332_4.pdf',
#  '2019-0332_5.pdf',
#  '2019-0333_1.pdf',
#  '2019-0334_1.pdf',
#  '2019-0336_1.pdf',
#  '2019-0337_1.pdf',
#  '2019-0340_1.pdf',
#  '2019-0341_1.pdf',
#  '2019-0343_1.pdf',
#  '2019-0344_1.pdf',
#  '2019-0345_1.pdf',
#  '2019-0347_1.pdf',
#  '2019-0352_1.pdf',
#  '2019-0352_2.pdf',
#  '2019-0352_3.pdf',
#  '2019-0352_4.pdf',
#  '2019-0353_1.pdf',
#  '2019-0357_1.pdf',
#  '2019-0360_1.pdf',
#  '2019-0371_1.pdf',
#  '2019-0371_2.pdf',
#  '2019-0384_1.pdf',
#  '2019-0445.pdf',
#  '2019-0446.pdf',
#  '2019-0447.pdf',
#  '2019-0448.pdf',
#  '2019-0449.pdf',
#  '2019-0451.pdf',
#  '2019-0452.pdf',
#  '2019-0453.pdf',
#  '2019-0454.pdf',
#  '2019-0455.pdf',
#  '2019-0456.pdf',
#  '2019-0457.pdf',
#  '2019-0458A.pdf',
#  '2019-0458A_1.pdf',
#  '2019-0459.pdf',
#  '2019-0460.pdf',
#  '2019-0461.pdf',
#  '2019-0462.pdf',
#  '2019-0463.pdf',
#  '2019-0464.pdf',
#  '2019-0465.pdf',
#  '2019–0450.pdf',
#  '2020-0001.pdf',
#  'Alan Walker.pdf',
#  'Alan Walker_1.pdf',
#  'Daniel Byrne.pdf',
#  'Daniel Byrne_1.pdf',
#  'Daniel Byrne_2.pdf',
#  'David Stacey.pdf',
#  'Elsie Brown.pdf',
#  'Elsie Brown_1.pdf',
#  'Julie Rose.pdf',
#  'Kamrul Rubel.pdf',
#  'Kevin Gilbert.pdf',
#  'Kevin Gilbert_1.pdf',
#  'Margaret O’Brien.pdf',
#  'Paul Whitehead.pdf',
#  'Paul Whitehead_1.pdf',
#  'Ruth Smith.pdf',
#  'Ruth Smith_1.pdf',
#  'Stephen Buck.pdf',
#  'Stephen Buck_1.pdf',
#  'Tahnie Martin.pdf',
#  'Tahnie Martin_1.pdf',
#  'William Driscoll.pdf',
#  'William Maskell.pdf',
#  'William Maskell_1.pdf',
#  'William Maskell_2.pdf']

# %%
len(new_not_old_list)
# Out:
# 399

# %%
import pandas as pd

feb = pd.read_csv('death_info_2020-02-05.csv')
aug = pd.read_csv('death_info_2020-08-13.csv')

# %%
cols = list(aug.columns)
merged = aug.merge(feb, on=cols, how='left', indicator=True)

# %%
l_only = merged[merged['_merge'] == 'left_only']

# %%
len(l_only)
# Out:
# 258

# %%
l_only
# Out:
#           date_of_report         ref      deceased_name  \
# 0            28 May 2020   2020-0122     Michael Pender
# 1            28 May 2020   2020-0121      Gillian Davey
# 2       27 December 2019   2020-0120         Enid Baber
# 3       28 February 2020   2020-0123         Peter Cole
# 4        20 January 2016   2016-0600        Faiza Ahmed
# 5           24 July 2015   2015-0475   Miriam Smith-Cox
# 6       10 February 2020   2020-0119        Sarah Young
# 7      24 September 2019   2020-0118      Iain Macinnes
# 8       17 December 2019   2019-0510       Jamie Finlay
# 9        5 February 2020   2020-0116      Adam Bojelian
# 10           29 May 2020   2020-0115         Flora Shen
# 11           29 May 2020   2020-0114     Omarian Brooks
# 12           28 May 2020   2020-0113       Lesley Brass
# 13           15 May 2020   2020-0112     Lynda Pedersen
# 14           12 May 2020   2020-0111   Harrison Hassall
# 15            4 May 2020   2020-0110      Barry Preston
# 16      12 February 2020   2020-0109     Donald Elliott
# 17            1 May 2020   2020-0108    Barrie Copeland
# 18    27 January 2020Ref         NaN                NaN
# 19         27 April 2020   2020-0106        Evelyn Ross
# 20         24 April 2020   2020-0105         Mary Brady
# 21         24 April 2020   2020-0104        Dean George
# 22         20 April 2020   2020-0103       Andrew Jones
# 23         23 April 2020   2020-0102      Gordon Fenton
# 24          15 July 2019   2019-0509           Lucy Lee
# 25          15 July 2019  2019-0509A      Christine Lee
# 26         22 April 2020   2020-0101        Sam Pringle
# 27         22 April 2020   2020-0100         David Kerr
# 28         22 April 2020   2020-0099     Allan Cunliffe
# 29         22 April 2020   2020-0098      Norman Baxter
# ...                  ...         ...                ...
# 2130   11 September 2015         NaN   George Ainsworth
# 2131   11 September 2015         NaN   Ronald Bonifield
# 2132   11 September 2015         NaN    Thomas Nicholls
# 2133    8 September 2015         NaN      David Efemena
# 2134    8 September 2015         NaN         Ian Emsley
# 2135    8 September 2015         NaN       Andrew Frere
# 2136    3 September 2015         NaN           May Hall
# 2137    3 September 2015         NaN       Kala Skinner
# 2138    2 September 2015         NaN     Rosalind Baird
# 2139    1 September 2015         NaN      John Robinson
# 2140    1 September 2015         NaN      Darren Browne
# 2141      28 August 2015         NaN  Isabel Richardson
# 2142      27 August 2015         NaN   Frederick Sutton
# 2143      27 August 2015         NaN      Eliza Simpson
# 2144      20 August 2015         NaN     Andrew Roberts
# 2145      20 August 2015         NaN      Joyce Plested
# 2146      20 August 2015         NaN       Elsie Clarke
# 2147      20 August 2015         NaN    Sharon Henshall
# 2148      19 August 2015         NaN         Barry Pike
# 2149      19 August 2018         NaN      David Sweeney
# 2155      12 August 2015         NaN         Ben Hiscox
# 2159    8 September 2015         NaN     Craig Chappell
# 2167    4 September 2015         NaN         Mary James
# 2195        20 July 2015         NaN         Luke Myers
# 2198        15 July 2015         NaN      Karen O’Brien
# 2221         6 July 2015         NaN      Tommy Faisali
# 2239        23 June 2015         NaN      Steven Curtis
# 2251        11 June 2015         NaN    Deborah Roberts
# 2272         22 May 2015         NaN   Olive Darbyshire
# 2494    18 December 2014         NaN     William Savage
#
#                    coroner_name                             coroner_area  \
# 0                    Andrew Cox         Cornwall and the Isles of Scilly
# 1                    Andrew Cox         Cornwall and the Isles of Scilly
# 2                   Gordon Clow           Nottinghamshire and Nottingham
# 3             Geoffrey Sullivan                            Hertfordshire
# 4                  Mary Hassell                       Inner North London
# 5        Elizabeth Emma Carlyon          Cornwall and the Isle of Scilly
# 6                 Emma Whitting   Bedfordshire and Luton Coroner Service
# 7                   Tom Osborne                            Milton Keynes
# 8           Jacqueline Devonish                                  Suffolk
# 9              Kevin McLoughlin                    West Yorkshire (East)
# 10             Jonathan Stevens               London; Inner North London
# 11                          NaN               London; London Inner South
# 12              Robert Sowersby                                     Avon
# 13             Patricia Harding              Central and South East Kent
# 14    Professor Catherine Mason  Leicester City and South Leicestershire
# 15                 Alison Mutch     Manchester; Greater Manchester South
# 16                  Paul Cooper                             Lincolnshire
# 17                Jame Thompson                   Bedfordshire and Luton
# 18                          NaN                                      NaN
# 19                 Alison Mutch                 Greater Manchester South
# 20                 Alison Mutch                 Greater Manchester South
# 21               Colin Phillips            Swansea and Neath Port Talbot
# 22               Dr Jame Adeley     Lancashire and Blackburn with Darwin
# 23                Adrian Farrow                         Manchester South
# 24              Richard Travers                                   Surrey
# 25              Richard Travers                                   Surrey
# 26                  Jason Wells                         Manchester South
# 27                  Jason Wells                         Manchester South
# 28                  Jason Wells                         Manchester South
# 29                  Chri Morris                         Manchester South
# ...                         ...                                      ...
# 2130                 Alan Walsh                        Manchester (West)
# 2131              Graeme Hughes                                    Powys
# 2132                 Alan Walsh                        Manchester (West)
# 2133              Nadia Persaud                            London (East)
# 2134          Elizabeth Earland                   Exeter and Great Devon
# 2135               Neil Cameron                   South Yorkshire (East)
# 2136               John Pollard                       Manchester (South)
# 2137            Peter Harrowing                                     Avon
# 2138              David Horsley      Portsmouth and South East Hampshire
# 2139               David Urpeth                   South Yorkshire (West)
# 2140              Andrew Harris                     London Inner (South)
# 2141            Jacqueline Lake                                  Norfolk
# 2142               John Pollard                       Manchester (South)
# 2143                 Emma Brown                  Birmingham and Solihull
# 2144               John Gittins            North Wale (East and Central)
# 2145               John Pollard                       Manchester (South)
# 2146               John Pollard                       Manchester (South)
# 2147             Claire Hammond              Preston and West Lancashire
# 2148                 Andrew Cox          Plymouth Torbay and South Devon
# 2149                 ME Hassell                     London Inner (North)
# 2155                    T Moore                                     Avon
# 2159            Rosemary Baxter       East Riding and Kingston Upon-Hull
# 2167        Sarah-Jane Richards                                    Powys
# 2195              Andre Rebello                     Liverpool and Wirral
# 2198                 Roy Palmer                            London (City)
# 2221               Fiona Wilcox                      London Inner (West)
# 2239              Darren Salter                              Oxfordshire
# 2251           Patricia Harding                        Mid Kent & Medway
# 2272                Alan Wilson                  Blackpool and The Fylde
# 2494              Darren Salter                              Oxfordshire
#
#                                                category  \
# 0                                  Other related deaths
# 1                                  Other related deaths
# 2                                  Other related deaths
# 3     Alcohol, drug and medication related deaths; O...
# 4     Emergency Services related deaths; Mental Heal...
# 5     Community healthcare related deaths; Other rel...
# 6     Hospital Death (Clinical Procedures and medica...
# 7     Mental Health related deaths; Community health...
# 8                 Road (Highways Safety) related deaths
# 9         Child Death (from 2015); Other related deaths
# 10                               Railway related deaths
# 11                  Community healthcare related deaths
# 12    Hospital Death (Clinical Procedures and medica...
# 13    Hospital Death (Clinical Procedures and medica...
# 14    Community healthcare related deaths; Child Deaths
# 15    Hospital Death (Clinical Procedures and medica...
# 16    Care Home Health related deaths; Other related...
# 17                                 Other related deaths
# 18                                                  NaN
# 19    Hospital Death (Clinical Procedures and medica...
# 20    Care Home Health related deaths; Mental Health...
# 21    Alcohol, drug and medication related deaths; S...
# 22    Alcohol, drug and medication related deaths; S...
# 23    Hospital Death (Clinical procedures and medica...
# 24                                 Other related deaths
# 25                                 Other related deaths
# 26    Mental Health related deaths; Suicide (from 20...
# 27    Other related deaths; Hospital Death (Clinical...
# 28    Hospital Death (Clinical Procedures and medica...
# 29                      Care home health related deaths
# ...                                                 ...
# 2130              Road (Highways Safety) related deaths
# 2131  Community health care and emergency services r...
# 2132                    Care Home Health related deaths
# 2133                   Service Personnel related deaths
# 2134                       State Custody related deaths
# 2135                       State Custody related deaths
# 2136                    Care Home Health related deaths
# 2137  Community health care and emergency services r...
# 2138  Hospital Death (Clinical Procedures and medica...
# 2139  Community health care and emergency services r...
# 2140                               Other related deaths
# 2141                               Other related deaths
# 2142  Hospital Death (Clinical Procedures and medica...
# 2143                    Care Home Health related deaths
# 2144  Hospital Death (Clinical Procedures and medica...
# 2145                               Other related deaths
# 2146                    Care Home Health related deaths
# 2147  Hospital Death (Clinical Procedures and medica...
# 2148  Hospital Death (Clinical Procedures and medica...
# 2149  Community health care and emergency services r...
# 2155                               Other related deaths
# 2159                       State Custody related deaths
# 2167  Hospital Death (Clinical Procedures and medica...
# 2195                       State Custody related deaths
# 2198  Hospital Death (Clinical Procedures and medica...
# 2221  Hospital Death (Clinical Procedures and medica...
# 2239                             Product related deaths
# 2251              Road (Highways Safety) related deaths
# 2272  Hospital Death (Clinical Procedures and medica...
# 2494                   Service Personnel related deaths
#
#                            this_report_is_being_sent_to  \
# 0     Department for Transport; Maritime and Coastgu...
# 1     Department for Transport; Maritime and Coastgu...
# 2                        Nottinghamshire County Council
# 3                                           NHS England
# 4     Metropolitan Police; London Ambulance Service ...
# 5     Cornwall Council; Pluss Work Choice; Devon and...
# 6                            Bedford Hospital NHS Trust
# 7         Central Northwest London NHS Foundation Trust
# 8     Transport and Rural Affairs at Suffolk County ...
# 9                    Leeds Teaching Hospitals NHS Trust
# 10    The Office of Rail & Road; Transport for Londo...
# 11    London Ambulance Service; London Borough of Le...
# 12                              North Bristol NHS Trust
# 13    East Kent University Hospital NHS Trust; NHS E...
# 14                 Department of Health and Social Care
# 15    Greater Manchester Mental Health NHS Foundatio...
# 16                Glenholme Holdingham Grange Care Home
# 17    TUI UK & Ireland, Wigmore House, Wigmore Place...
# 18                                                  NaN
# 19    Manchester University Foundation Trust (MFT); ...
# 20    Care Quality Commission (CQC); Department of S...
# 21                                 Department of Health
# 22                         National Offender Management
# 23    Tameside and Glossop Integrated Care NHS Found...
# 24    Surrey Police; The National Police Chief’s Cou...
# 25    Surrey Police; The National Police Chief’s Cou...
# 26    Greater Manchester Medicines Management Group;...
# 27                       Stockport NHS Foundation Trust
# 28                    Pennine Care NHS Foundation Trust
# 29                                 Lynmere Nursing home
# ...                                                 ...
# 2130                                     Bolton Council
# 2131                            University Health Board
# 2132                                 Orchard Care Homes
# 2133                                                MOD
# 2134                            HMP Exter; HMP Portland
# 2135                                                MOJ
# 2136                                       Bourne House
# 2137               CQC; South Western Ambulance Service
# 2138                               Department of Health
# 2139                                                CCG
# 2140                                Metropolitan Police
# 2141                                      Hewett School
# 2142                                Stockport NHS Trust
# 2143                       Birmingham City Council; CQC
# 2144                                              BCUHB
# 2145           Sainsburys PLC; Trafford Borough Council
# 2146                             Hurst Hall Care Centre
# 2147                                              LTHTR
# 2148                       Plymouth Hospitals NHS Trust
# 2149                 London Ambulance Service NHS Trust
# 2155                                           FA Group
# 2159                                         HMP Humber
# 2167                            University Health Board
# 2195                                               NOMS
# 2198            NICE; South Essex Partnership NHS Trust
# 2221                                     CNWL NHS Trust
# 2239                                  Trading Standards
# 2251                                   Highways England
# 2272              Blackpool Teaching Hospital NHS Trust
# 2494                                                NaN
#
#                                                     url     _merge
# 0     https://www.judiciary.uk/publications/michael-...  left_only
# 1     https://www.judiciary.uk/publications/gillian-...  left_only
# 2     https://www.judiciary.uk/publications/enid-baber/  left_only
# 3     https://www.judiciary.uk/publications/peter-cole/  left_only
# 4     https://www.judiciary.uk/publications/faiza-ah...  left_only
# 5     https://www.judiciary.uk/publications/miriam-s...  left_only
# 6     https://www.judiciary.uk/publications/sarah-yo...  left_only
# 7     https://www.judiciary.uk/publications/iain-mac...  left_only
# 8     https://www.judiciary.uk/publications/jamie-fi...  left_only
# 9     https://www.judiciary.uk/publications/adam-boj...  left_only
# 10    https://www.judiciary.uk/publications/flora-shen/  left_only
# 11    https://www.judiciary.uk/publications/omarian-...  left_only
# 12    https://www.judiciary.uk/publications/lesley-b...  left_only
# 13    https://www.judiciary.uk/publications/lynda-pe...  left_only
# 14    https://www.judiciary.uk/publications/harrison...  left_only
# 15    https://www.judiciary.uk/publications/barry-pr...  left_only
# 16    https://www.judiciary.uk/publications/donald-e...  left_only
# 17    https://www.judiciary.uk/publications/barrie-c...  left_only
# 18    https://www.judiciary.uk/publications/helen-sh...  left_only
# 19    https://www.judiciary.uk/publications/evelyn-r...  left_only
# 20    https://www.judiciary.uk/publications/mary-brady/  left_only
# 21    https://www.judiciary.uk/publications/dean-geo...  left_only
# 22    https://www.judiciary.uk/publications/andrew-j...  left_only
# 23    https://www.judiciary.uk/publications/gordon-f...  left_only
# 24      https://www.judiciary.uk/publications/lucy-lee/  left_only
# 25    https://www.judiciary.uk/publications/christin...  left_only
# 26    https://www.judiciary.uk/publications/sam-prin...  left_only
# 27    https://www.judiciary.uk/publications/david-kerr/  left_only
# 28    https://www.judiciary.uk/publications/allan-cu...  left_only
# 29    https://www.judiciary.uk/publications/norman-b...  left_only
# ...                                                 ...        ...
# 2130  https://www.judiciary.uk/publications/george-a...  left_only
# 2131  https://www.judiciary.uk/publications/ronald-b...  left_only
# 2132  https://www.judiciary.uk/publications/thomas-n...  left_only
# 2133  https://www.judiciary.uk/publications/david-ef...  left_only
# 2134  https://www.judiciary.uk/publications/ian-emsley/  left_only
# 2135  https://www.judiciary.uk/publications/andrew-f...  left_only
# 2136    https://www.judiciary.uk/publications/may-hall/  left_only
# 2137  https://www.judiciary.uk/publications/kala-ski...  left_only
# 2138  https://www.judiciary.uk/publications/rosalind...  left_only
# 2139  https://www.judiciary.uk/publications/john-rob...  left_only
# 2140  https://www.judiciary.uk/publications/darren-b...  left_only
# 2141  https://www.judiciary.uk/publications/isabel-r...  left_only
# 2142  https://www.judiciary.uk/publications/frederic...  left_only
# 2143  https://www.judiciary.uk/publications/eliza-si...  left_only
# 2144  https://www.judiciary.uk/publications/andrew-r...  left_only
# 2145  https://www.judiciary.uk/publications/joyce-pl...  left_only
# 2146  https://www.judiciary.uk/publications/elsie-cl...  left_only
# 2147  https://www.judiciary.uk/publications/sharon-h...  left_only
# 2148  https://www.judiciary.uk/publications/barry-pike/  left_only
# 2149  https://www.judiciary.uk/publications/david-sw...  left_only
# 2155  https://www.judiciary.uk/publications/ben-hiscox/  left_only
# 2159  https://www.judiciary.uk/publications/craig-ch...  left_only
# 2167  https://www.judiciary.uk/publications/mary-james/  left_only
# 2195  https://www.judiciary.uk/publications/luke-mye...  left_only
# 2198  https://www.judiciary.uk/publications/karen-ob...  left_only
# 2221  https://www.judiciary.uk/publications/tommy-fa...  left_only
# 2239  https://www.judiciary.uk/publications/steven-c...  left_only
# 2251  https://www.judiciary.uk/publications/deborah-...  left_only
# 2272  https://www.judiciary.uk/publications/olive-da...  left_only
# 2494  https://www.judiciary.uk/publications/william-...  left_only
#
# [258 rows x 9 columns]

# %%
l_only.to_csv(r'death_info_newaug.csv')
